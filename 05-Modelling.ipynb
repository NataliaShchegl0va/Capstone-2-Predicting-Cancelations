# %% [markdown]
# I have a classification problem, I will try Logistic regression, KNN classifier, Decision Tree and Random forest. After initial assessment of which model is better I will work on tuning the model.

# %%
#Loading libraries
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import __version__ as sklearn_version
from sklearn.model_selection import cross_val_score, cross_validate, StratifiedKFold
from imblearn.over_sampling import SMOTE
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree
from io import StringIO
from IPython.display import Image  
import pydotplus
from bayes_opt import BayesianOptimization
import datetime
from library.sb_utils import save_file

# %%
# Loading data
X_train = pd.read_csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')

X_test = pd.read_csv('X_test.csv')
y_test = pd.read_csv('y_test.csv')

# %%
#Checking proportion of classes in target feature
y_train.value_counts(normalize=True)
# Out:
# Status Category
# 0                  0.855504
# 1                  0.144496
# Name: proportion, dtype: float64

# %% [markdown]
# The classes in my target feature are imbalanced. I can't use accuracy as my model assessment metric, because the dumb model that assigns "No cancellation" label to each observation will have accuracy of 85%. I will use recall for 'Status' class = 1 (cancellation) as my main metric. And will keep an eye on recall for 'Status' class = 0.

# %% [markdown]
# ## Logistic Regression

# %%
# Initializing and fitting the model. I'm using class_weight = 'balanced' to accomodate for imbalanced 
# classes of target feature.

classifier = LogisticRegression(class_weight = 'balanced', solver = 'liblinear', max_iter = 500, C = 1000) #solver = 'newton-cg'
classifier.fit(X_train, y_train)
# Out:
# /Users/nataliiashcheglova/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1000, class_weight='balanced', max_iter=500,
#                    solver='liblinear')

# %%
print(f'Accuracy on training data: {accuracy_score(classifier.predict(X_train), y_train):.2f}')
print(f'Accuracy on test data: {accuracy_score(classifier.predict(X_test), y_test):.2f}')
# Out:
# Accuracy on training data: 0.80
# Accuracy on test data: 0.81

# %%
print("Classification Report for Training Data")
print(classification_report(y_train, classifier.predict(X_train)))
# Out:
# Classification Report for Training Data
#               precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87     72030
#            1       0.42      0.94      0.58     12166
#
#     accuracy                           0.80     84196
#    macro avg       0.70      0.86      0.73     84196
# weighted avg       0.91      0.80      0.83     84196

# %%
print("Classification Report for Test Data")
print(classification_report(y_test, classifier.predict(X_test)))
# Out:
# Classification Report for Test Data
#               precision    recall  f1-score   support
#
#            0       0.99      0.78      0.87     31007
#            1       0.42      0.94      0.58      5077
#
#     accuracy                           0.81     36084
#    macro avg       0.70      0.86      0.73     36084
# weighted avg       0.91      0.81      0.83     36084

# %% [markdown]
#   Logistic regression model produced pretty good results. Recall for 'Cancelled' on test data is 94%.

# %% [markdown]
# ## KNN Classifier model

# %%
# Changing features to array
X_train2 = np.array(X_train)
y_train2 = np.array(y_train)
X_test2 = np.array(X_test)
y_test2 = np.array(y_test)

# %%
# Resampling data set
smote = SMOTE()
X_resampled, y_resampled = smote.fit_resample(X_train2, y_train2)

# %%
# Checking which n_neighbours parameter will produce better accuracy score
recall_scores = []

for i in range(3,12,2): #iterating through uneven numbers only

    knn = KNeighborsClassifier(i)
    knn.fit(X_resampled,y_resampled)
    y_pred=knn.predict(X_test2)
    
    recall_scores.append(recall_score(y_test2,y_pred))

# %%
# Printing the results
n=3
for score in recall_scores:
    print(f"for {n} neighbours the recall is: {round(score,3)}") 
    n += 2
# Out:
# for 3 neighbours the recall is: 0.732
# for 5 neighbours the recall is: 0.778
# for 7 neighbours the recall is: 0.806
# for 9 neighbours the recall is: 0.829
# for 11 neighbours the recall is: 0.843

# %%
# Plotting the results
plt.figure(figsize=(12,5))
p = sns.lineplot(x=range(3,12,2),y=recall_scores,marker='*',label='Recall')
#p = sns.lineplot(x=range(3,12,2),y=test_scores,marker='o',label='Test Score')
# Out:
# /Users/nataliiashcheglova/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliiashcheglova/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Max recall has a model with n_neighbours=11
knn = KNeighborsClassifier(11)
knn.fit(X_resampled,y_resampled)
  
train_score = knn.score(X_resampled,y_resampled)
test_score = knn.score(X_test2, y_test2)

print(f"train score: {train_score}, test score: {test_score}")
# Out:
# train score: 0.9022351797862002, test score: 0.8031260392417692

# %%
y_pred2 = knn.predict(X_test2)

# %%
report = classification_report(y_test2, y_pred2)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.87     31007
#            1       0.40      0.84      0.55      5077
#
#     accuracy                           0.80     36084
#    macro avg       0.69      0.82      0.71     36084
# weighted avg       0.89      0.80      0.83     36084

# %% [markdown]
# KNN model produced much worse results - only 84% recall for 'Cancelled'.

# %% [markdown]
# ## Random Forest Classifier

# %%
# Loading unscaled data for better interpretability
X_train_unscaled = pd.read_csv('X_train_unscaled.csv')
X_test_unscaled = pd.read_csv('X_test_unscaled.csv')
y_train_unscaled = pd.read_csv('y_train_unscaled.csv')
y_test_unscaled = pd.read_csv('y_test_unscaled.csv')

# %%
X_train_unscaled.head()
# Out:
#         SKU    B2B  Easy Ship   Price  Free Financing  Free Shipping  Coupon  \
# 0  0.131697  False      False   799.0           False          False   False
# 1  0.132231  False       True   597.0           False          False   False
# 2  0.166667  False      False  1349.0           False          False   False
# 3  0.102210  False      False   788.0           False           True   False
# 4  0.134410  False      False   521.0           False          False   False
#
#    Other Promotions  No Promotions  Weekend  ...  \
# 0             False           True     True  ...
# 1             False           True     True  ...
# 2             False           True    False  ...
# 3             False          False    False  ...
# 4             False           True    False  ...
#
#    Shipment State Matched_Rajasthan  Shipment State Matched_Sikkim  \
# 0                             False                          False
# 1                             False                          False
# 2                             False                          False
# 3                             False                          False
# 4                             False                          False
#
#    Shipment State Matched_Tamil Nadu  Shipment State Matched_Telangana  \
# 0                              False                              True
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
#
#    Shipment State Matched_Tripura  Shipment State Matched_Uttar Pradesh  \
# 0                           False                                 False
# 1                           False                                  True
# 2                           False                                 False
# 3                           False                                 False
# 4                           False                                 False
#
#    Shipment State Matched_Uttarakhand  Shipment State Matched_West Bengal  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                                True
# 3                               False                               False
# 4                               False                               False
#
#    Shipment State Matched_apo  Shipment Type_Standard
# 0                       False                   False
# 1                       False                    True
# 2                       False                   False
# 3                       False                   False
# 4                       False                   False
#
# [5 rows x 70 columns]

# %%
# Fitting the model, predicting results, assessing accuracy  

rf = RandomForestClassifier(class_weight = 'balanced',n_estimators=300, n_jobs=-1)
rf.fit(X_train_unscaled, y_train_unscaled)

y_pred3 = rf.predict(X_test_unscaled)

ac = accuracy_score(y_test_unscaled, y_pred3)
print(f"Test accuracy score: {ac}")
# Out:
# /Users/nataliiashcheglova/anaconda3/lib/python3.11/site-packages/sklearn/base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Test accuracy score: 0.9128699700698371

# %%
# Printing classification report

cr = classification_report(y_test_unscaled, y_pred3)
print('Classification report:')
print(cr)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95     31007
#            1       0.77      0.55      0.64      5077
#
#     accuracy                           0.91     36084
#    macro avg       0.85      0.76      0.79     36084
# weighted avg       0.91      0.91      0.91     36084

# %% [markdown]
# Random Forest model produced higher accuracy than two previous models (91%), but it's much worse at predicting 'Cancelled' orders (only 55% recall).

# %% [markdown]
# ## Decision Tree

# %%
# Entropy model
entr_model = tree.DecisionTreeClassifier(class_weight = 'balanced',criterion="entropy",max_depth=3)
entr_model.fit(X_train_unscaled, y_train_unscaled)
 
y_pred4 = entr_model.predict(X_test_unscaled)
y_pred4 = pd.Series(y_pred4)

entr_model
# Out:
# DecisionTreeClassifier(class_weight='balanced', criterion='entropy',
#                        max_depth=3)

# %%
cr4 = classification_report(y_test_unscaled, y_pred4)
print('Classification report:')
print(cr4)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.72      0.84     31007
#            1       0.36      0.98      0.53      5077
#
#     accuracy                           0.76     36084
#    macro avg       0.68      0.85      0.68     36084
# weighted avg       0.91      0.76      0.79     36084

# %%
dot_data = StringIO()
tree.export_graphviz(entr_model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True, feature_names=pd.DataFrame(X_train_unscaled).columns,class_names = ["No cancellation", "Cancellation"])

# Alternatively for class_names use gini_model.classes_
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# Decision tree model produced better result than Logistic regression. The recall for 'Cancelled' class is 98%. The recall for 'Shipped' status (72%) is lower than in Logistic Regression (78%). If we don't have shortage of resources to contact all false positives, then we should choose Decision tree as our base model. Now I will focus on optimizing the model.

# %% [markdown]
# ## Bayesian optimization

# %%
# Defining the function to optimize using cross-validation
def dtree_cv(max_depth, min_samples_split, min_samples_leaf, criterion_index, max_features_index, max_leaf_nodes):
    
    # Mapping the numerical indices back to categorical parameters
    criterion = ['gini', 'entropy'][int(criterion_index)]
    max_features_options = ['sqrt', 'log2', None]
    max_features = max_features_options[int(max_features_index)]
   
    # Defining the model with the parameters to be optimized
    estimator = tree.DecisionTreeClassifier(class_weight = 'balanced',
        max_depth=int(max_depth),
        min_samples_split=int(min_samples_split),
        min_samples_leaf=int(min_samples_leaf),
        criterion=criterion,
        max_features=max_features,
        max_leaf_nodes=int(max_leaf_nodes)
    )
    
    # Using StratifiedKFold for cross-validation to handle imbalanced classes
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    cval = cross_val_score(estimator, X_train_unscaled, y_train_unscaled, scoring='recall', cv=skf)
    
    return cval.mean()

# Defining the parameter bounds
param_bounds = {
    'max_depth': (3, 12),
    'min_samples_split': (10, 100),
    'min_samples_leaf': (10, 100),
    'criterion_index': (0, 1),  # Index for criterion (0 = 'gini', 1 = 'entropy')
    'max_features_index': (0, 2),  # Index for max_features
    'max_leaf_nodes': (10, 100)
}

optimizer = BayesianOptimization(
    f=dtree_cv,
    pbounds=param_bounds,
    random_state=1,
)

optimizer.maximize(n_iter=25, init_points=5) # Bayesian optimization

# Extracting the best parameters
best_params_bayes = optimizer.max['params']
best_params_bayes['max_depth'] = int(best_params_bayes['max_depth'])
best_params_bayes['min_samples_split'] = int(best_params_bayes['min_samples_split'])
best_params_bayes['min_samples_leaf'] = int(best_params_bayes['min_samples_leaf'])
best_params_bayes['max_leaf_nodes'] = int(best_params_bayes['max_leaf_nodes'])

# Mapping back the categorical indices to their original values
best_params_bayes['criterion'] = ['gini', 'entropy'][int(best_params_bayes['criterion_index'])]
max_features_options = ['sqrt', 'log2', None]
best_params_bayes['max_features'] = max_features_options[int(best_params_bayes['max_features_index'])]

# Removing the indices from best_params_bayes dictionary
del best_params_bayes['criterion_index']
del best_params_bayes['max_features_index']

best_score_bayes = optimizer.max['target']

print(f"Best Parameters (Bayesian Optimization): {best_params_bayes}")
print(f"Best Score (Bayesian Optimization): {best_score_bayes}")
# Out:
# |   iter    |  target   | criter... | max_depth | max_fe... | max_le... | min_sa... | min_sa... |
# -------------------------------------------------------------------------------------------------
# | 1         | 0.9413    | 0.417     | 9.483     | 0.0002287 | 37.21     | 23.21     | 18.31     |
# | 2         | 0.9673    | 0.1863    | 6.11      | 0.7935    | 58.49     | 47.73     | 71.67     |
# | 3         | 0.9554    | 0.2045    | 10.9      | 0.05478   | 70.34     | 47.56     | 60.28     |
# | 4         | 0.8439    | 0.1404    | 4.783     | 1.601     | 97.14     | 38.21     | 72.31     |
# | 5         | 0.5695    | 0.8764    | 11.05     | 0.1701    | 13.51     | 25.28     | 89.03     |
# | 6         | 0.7757    | 0.695     | 6.585     | 1.508     | 57.54     | 48.33     | 71.55     |
# | 7         | 0.8515    | 0.1956    | 6.119     | 0.8028    | 58.5      | 47.74     | 71.68     |
# | 8         | 0.862     | 0.5567    | 3.252     | 1.888     | 96.11     | 78.65     | 88.7      |
# | 9         | 0.8159    | 0.1856    | 8.478     | 1.03      | 35.42     | 15.85     | 16.65     |
# | 10        | 0.9335    | 0.394     | 9.153     | 0.3472    | 39.67     | 38.74     | 47.1      |
# | 11        | 0.9439    | 0.008471  | 6.05      | 1.197     | 14.93     | 68.33     | 50.25     |
# | 12        | 0.9558    | 0.259     | 11.68     | 0.3366    | 80.69     | 51.05     | 29.33     |
# | 13        | 0.6864    | 0.3306    | 4.455     | 0.5277    | 65.38     | 42.6      | 97.89     |
# | 14        | 0.9314    | 0.1208    | 5.316     | 0.3379    | 93.56     | 59.91     | 38.17     |
# | 15        | 0.8654    | 0.3846    | 8.62      | 0.9437    | 55.52     | 81.82     | 97.24     |
# | 16        | 0.8325    | 0.3724    | 10.23     | 1.864     | 11.65     | 73.69     | 26.58     |
# | 17        | 0.9206    | 0.6069    | 10.09     | 0.0008749 | 60.13     | 79.74     | 17.29     |
# | 18        | 0.8017    | 0.8528    | 6.249     | 0.4805    | 44.61     | 39.71     | 92.07     |
# | 19        | 0.7967    | 0.3663    | 4.635     | 1.746     | 60.6      | 66.32     | 92.42     |
# | 20        | 0.7438    | 0.5907    | 3.406     | 1.303     | 70.5      | 20.88     | 48.16     |
# | 21        | 0.9411    | 0.1809    | 6.107     | 0.79      | 58.49     | 47.72     | 71.67     |
# | 22        | 0.6884    | 0.8187    | 3.819     | 0.346     | 24.78     | 97.52     | 51.17     |
# | 23        | 0.9185    | 0.8113    | 10.93     | 0.7022    | 99.72     | 22.02     | 65.07     |
# | 24        | 0.9176    | 0.775     | 8.585     | 0.1772    | 73.14     | 77.42     | 19.3      |
# | 25        | 0.8364    | 0.8888    | 3.852     | 0.1528    | 88.44     | 75.2      | 89.99     |
# | 26        | 0.9392    | 0.4159    | 10.56     | 0.2151    | 15.2      | 88.1      | 96.31     |
# | 27        | 0.9231    | 0.8889    | 9.248     | 0.7174    | 91.35     | 90.37     | 90.13     |
# | 28        | 0.9181    | 0.2388    | 10.05     | 0.9677    | 34.09     | 76.95     | 34.51     |
# | 29        | 0.9541    | 0.8708    | 6.131     | 0.05669   | 94.15     | 54.79     | 46.36     |
# | 30        | 0.7579    | 0.4706    | 7.23      | 1.282     | 54.65     | 89.65     | 56.99     |
# =================================================================================================
# Best Parameters (Bayesian Optimization): {'max_depth': 6, 'max_leaf_nodes': 58, 'min_samples_leaf': 47, 'min_samples_split': 71, 'criterion': 'gini', 'max_features': 'sqrt'}
# Best Score (Bayesian Optimization): 0.9672854184840665

# %% [markdown]
# ## Creating final model

# %%
best_model = tree.DecisionTreeClassifier(class_weight = 'balanced',
                                         max_depth=6,
                                         criterion="gini",
                                         max_leaf_nodes=58,
                                         min_samples_leaf=47,
                                         min_samples_split=71,
                                         max_features = 'sqrt')

best_model.fit(X_train_unscaled, y_train_unscaled)

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
best_model_cv_results = cross_validate(best_model, X_train_unscaled, y_train_unscaled, cv=skf)

y_pred6 = best_model.predict(X_test_unscaled) 
y_pred6 = pd.Series(y_pred6)

cr6 = classification_report(y_test_unscaled, y_pred6)
print('Classification report:')
print(cr6)
# Out:
# Classification report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.64      0.78     31007
#            1       0.31      0.98      0.47      5077
#
#     accuracy                           0.69     36084
#    macro avg       0.65      0.81      0.62     36084
# weighted avg       0.90      0.69      0.73     36084

# %%
# Visualizing the tree
dot_data2 = StringIO()
tree.export_graphviz(best_model, out_file=dot_data2,  
                filled=True, rounded=True,
                special_characters=True, feature_names=pd.DataFrame(X_train).columns,class_names = ["No cancellation", "Cancellation"])

# Alternatively for class_names use gini_model.classes_
graph2 = pydotplus.graph_from_dot_data(dot_data2.getvalue())  
Image(graph2.create_png())

# %%
importances = best_model.feature_importances_

# Print feature importances
for feature, importance in zip(X_train_unscaled.columns, importances):
    print(f"Feature: {feature}, Importance: {importance:.4f}")
# Out:
# Feature: SKU, Importance: 0.0004
# Feature: B2B, Importance: 0.0000
# Feature: Easy Ship, Importance: 0.0024
# Feature: Price, Importance: 0.0047
# Feature: Free Financing, Importance: 0.4138
# Feature: Free Shipping, Importance: 0.5046
# Feature: Coupon, Importance: 0.0135
# Feature: Other Promotions, Importance: 0.0000
# Feature: No Promotions, Importance: 0.0550
# Feature: Weekend, Importance: 0.0000
# Feature: Stock, Importance: 0.0000
# Feature: Month, Importance: 0.0000
# Feature: DayofMonth, Importance: 0.0000
# Feature: begin_of_month, Importance: 0.0000
# Feature: midddle_of_month, Importance: 0.0000
# Feature: end_of_month, Importance: 0.0001
# Feature: Category_Bottom, Importance: 0.0000
# Feature: Category_Ethnic Dress, Importance: 0.0000
# Feature: Category_Saree, Importance: 0.0000
# Feature: Category_Set, Importance: 0.0001
# Feature: Category_Top, Importance: 0.0005
# Feature: Category_Western Dress, Importance: 0.0000
# Feature: Category_kurta, Importance: 0.0005
# Feature: Size_4XL, Importance: 0.0000
# Feature: Size_5XL, Importance: 0.0000
# Feature: Size_6XL, Importance: 0.0000
# Feature: Size_Free, Importance: 0.0000
# Feature: Size_L, Importance: 0.0000
# Feature: Size_M, Importance: 0.0000
# Feature: Size_S, Importance: 0.0000
# Feature: Size_XL, Importance: 0.0001
# Feature: Size_XS, Importance: 0.0001
# Feature: Size_XXL, Importance: 0.0000
# Feature: Shipment State Matched_Andhra Pradesh, Importance: 0.0000
# Feature: Shipment State Matched_Arunachal Pradesh, Importance: 0.0000
# Feature: Shipment State Matched_Assam, Importance: 0.0000
# Feature: Shipment State Matched_Bihar, Importance: 0.0000
# Feature: Shipment State Matched_Chandigarh, Importance: 0.0000
# Feature: Shipment State Matched_Chhattisgarh, Importance: 0.0000
# Feature: Shipment State Matched_Dadra and Nagar Haveli and Daman and Diu, Importance: 0.0000
# Feature: Shipment State Matched_Delhi, Importance: 0.0000
# Feature: Shipment State Matched_Goa, Importance: 0.0000
# Feature: Shipment State Matched_Gujarat, Importance: 0.0000
# Feature: Shipment State Matched_Haryana, Importance: 0.0000
# Feature: Shipment State Matched_Himachal Pradesh, Importance: 0.0000
# Feature: Shipment State Matched_Jammu and Kashmir, Importance: 0.0000
# Feature: Shipment State Matched_Jharkhand, Importance: 0.0000
# Feature: Shipment State Matched_Karnataka, Importance: 0.0000
# Feature: Shipment State Matched_Kerala, Importance: 0.0014
# Feature: Shipment State Matched_Ladakh, Importance: 0.0000
# Feature: Shipment State Matched_Lakshadweep, Importance: 0.0000
# Feature: Shipment State Matched_Madhya Pradesh, Importance: 0.0000
# Feature: Shipment State Matched_Maharashtra, Importance: 0.0000
# Feature: Shipment State Matched_Manipur, Importance: 0.0000
# Feature: Shipment State Matched_Meghalaya, Importance: 0.0000
# Feature: Shipment State Matched_Mizoram, Importance: 0.0000
# Feature: Shipment State Matched_Nagaland, Importance: 0.0000
# Feature: Shipment State Matched_Odisha, Importance: 0.0009
# Feature: Shipment State Matched_Puducherry, Importance: 0.0000
# Feature: Shipment State Matched_Punjab, Importance: 0.0000
# Feature: Shipment State Matched_Rajasthan, Importance: 0.0000
# Feature: Shipment State Matched_Sikkim, Importance: 0.0000
# Feature: Shipment State Matched_Tamil Nadu, Importance: 0.0000
# Feature: Shipment State Matched_Telangana, Importance: 0.0000
# Feature: Shipment State Matched_Tripura, Importance: 0.0000
# Feature: Shipment State Matched_Uttar Pradesh, Importance: 0.0000
# Feature: Shipment State Matched_Uttarakhand, Importance: 0.0000
# Feature: Shipment State Matched_West Bengal, Importance: 0.0001
# Feature: Shipment State Matched_apo, Importance: 0.0000
# Feature: Shipment Type_Standard, Importance: 0.0016

# %%
# Visualising features by importance
plt.subplots(figsize=(10, 5))
rf_feat_imps = pd.Series(importances, index=X_train_unscaled.columns).head(10).sort_values(ascending=False)
rf_feat_imps.plot(kind='bar')
plt.xlabel('features')
plt.ylabel('importance')
plt.title('Feature importances to explain cancelations');

# %%
# Saving basic info about model
best_model.version = 2
best_model.pandas_version = pd.__version__
best_model.numpy_version = np.__version__
best_model.sklearn_version = sklearn_version
best_model.X_columns = [col for col in X_train.columns]
best_model.build_datetime = datetime.datetime.now()

# %%
# saving the model

modelpath = '../models'
save_file(best_model, 'decision_tree_cancellations.pkl', modelpath)
# Out:
# Directory ../models was created.
# Writing file.  "../models/decision_tree_cancellations.pkl"
